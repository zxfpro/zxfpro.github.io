# %% [markdown]
# # 抓包和反编译

# %%
# !pip install pyshark
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting pyshark
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/1d/d9/7884ff926c3d05ec65fdf84ac499fb0f088e440d02c606b0ac41645605de/pyshark-0.6-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 3.5 MB/s eta 0:00:00
# Requirement already satisfied: lxml in /Users/zhaoxuefeng/opt/miniconda3/envs/py310_new/lib/python3.10/site-packages (from pyshark) (5.2.1)
# Requirement already satisfied: termcolor in /Users/zhaoxuefeng/opt/miniconda3/envs/py310_new/lib/python3.10/site-packages (from pyshark) (2.4.0)
# Requirement already satisfied: packaging in /Users/zhaoxuefeng/opt/miniconda3/envs/py310_new/lib/python3.10/site-packages (from pyshark) (23.2)
# Requirement already satisfied: appdirs in /Users/zhaoxuefeng/opt/miniconda3/envs/py310_new/lib/python3.10/site-packages (from pyshark) (1.4.4)
# Installing collected packages: pyshark
# Successfully installed pyshark-0.6

# %%
import pyshark
import time
# 捕获网络接口上的流量
capture = pyshark.LiveCapture(interface='Wi-Fi')

# 捕获流量，设置超时时间为50秒
capture.sniff(timeout=10)

# 打印捕获到的数据包
for packet in capture:
    print('====|cap|=====')
    print(packet)
    time.sleep(0.1)
# Out:
# ====|cap|=====
# Packet (Length: 315)
# Layer ETH
# :	Destination: 3c:9d:56:e1:2f:c6
# 	Address: 3c:9d:56:e1:2f:c6
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: f8:4d:89:80:34:90
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: f8:4d:89:80:34:90
# Layer IP
# :	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x00 (DSCP: CS0, ECN: Not-ECT)
# 	0000 00.. = Differentiated Services Codepoint: Default (0)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 301
# 	Identification: 0x0000 (0)
# 	010. .... = Flags: 0x2, Don't fragment
# 	0... .... = Reserved bit: Not set
# 	.1.. .... = Don't fragment: Set
# 	..0. .... = More fragments: Not set
# 	...0 0000 0000 0000 = Fragment Offset: 0
# 	Time to Live: 64
# 	Protocol: TCP (6)
# 	Header Checksum: 0xbf12 [validation disabled]
# 	Header checksum status: Unverified
# 	Source Address: 192.168.6.104
# 	Destination Address: 36.156.143.12
# Layer TCP
# :	Source Port: 64342
# 	Destination Port: 22328
# 	Stream index: 0
# 	Conversation completeness: Incomplete (0)
# 	..0. .... = RST: Absent
# 	...0 .... = FIN: Absent
# 	.... 0... = Data: Absent
# 	.... .0.. = ACK: Absent
# 	.... ..0. = SYN-ACK: Absent
# 	.... ...0 = SYN: Absent
# 	Completeness Flags: [ Null ]
# 	TCP Segment Len: 249
# 	Sequence Number: 1    (relative sequence number)
# 	Sequence Number (raw): 2854808504
# 	Next Sequence Number: 250    (relative sequence number)
# 	Acknowledgment Number: 1    (relative ack number)
# 	Acknowledgment number (raw): 3727731152
# 	1000 .... = Header Length: 32 bytes (8)
# 	Flags: 0x018 (PSH, ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Accurate ECN: Not set
# 	.... 0... .... = Congestion Window Reduced: Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 1... = Push: Set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: ·······AP···
# 	Window: 2048
# 	Calculated window size: 2048
# 	Window size scaling factor: -1 (unknown)
# 	Checksum: 0xf0c2 [unverified]
# 	Checksum Status: Unverified
# 	Urgent Pointer: 0
# 	Options: (12 bytes), No-Operation (NOP), No-Operation (NOP), Timestamps
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	TCP Option - Timestamps: TSval 861740014, TSecr 3920223889
# 	Length: 10
# 	Timestamp value: 861740014
# 	Timestamp echo reply: 3920223889
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.000000000 seconds
# 	Time since previous frame in this TCP stream: 0.000000000 seconds
# 	SEQ/ACK analysis
# 	Bytes in flight: 249
# 	Bytes sent since last PSH flag: 249
# 	TCP payload (249 bytes)
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	Kind: Time Stamp Option (8)
# DATA
# ====|cap|=====
# Packet (Length: 60)
# Layer ETH
# :	Destination: f8:4d:89:80:34:90
# 	Address: f8:4d:89:80:34:90
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: 3c:9d:56:e1:2f:c6
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Trailer: 00002a5998b3
# 	Expert Info (Note/Protocol): Didn't find padding of zeros, and an undecoded trailer exists. There may be padding of non-zeros.
# 	Didn't find padding of zeros, and an undecoded trailer exists. There may be padding of non-zeros.
# 	Severity level: Note
# 	Group: Protocol
# 	Address: 3c:9d:56:e1:2f:c6
# Layer IP
# :	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x74 (DSCP: Unknown, ECN: Not-ECT)
# 	0111 01.. = Differentiated Services Codepoint: Unknown (29)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 40
# 	Identification: 0xf86e (63598)
# 	010. .... = Flags: 0x2, Don't fragment
# 	0... .... = Reserved bit: Not set
# 	.1.. .... = Don't fragment: Set
# 	..0. .... = More fragments: Not set
# 	...0 0000 0000 0000 = Fragment Offset: 0
# 	Time to Live: 43
# 	Protocol: TCP (6)
# 	Header Checksum: 0x57fb [validation disabled]
# 	Header checksum status: Unverified
# 	Source Address: 111.124.200.101
# 	Destination Address: 192.168.6.104
# Layer TCP
# :	Source Port: 80
# 	Destination Port: 55965
# 	Stream index: 1
# 	Conversation completeness: Incomplete (0)
# 	..0. .... = RST: Absent
# 	...0 .... = FIN: Absent
# 	.... 0... = Data: Absent
# 	.... .0.. = ACK: Absent
# 	.... ..0. = SYN-ACK: Absent
# 	.... ...0 = SYN: Absent
# 	Completeness Flags: [ Null ]
# 	TCP Segment Len: 0
# 	Sequence Number: 1    (relative sequence number)
# 	Sequence Number (raw): 3843808128
# 	Next Sequence Number: 2    (relative sequence number)
# 	Acknowledgment Number: 1    (relative ack number)
# 	Acknowledgment number (raw): 721421610
# 	0101 .... = Header Length: 20 bytes (5)
# 	Flags: 0x011 (FIN, ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Accurate ECN: Not set
# 	.... 0... .... = Congestion Window Reduced: Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 0... = Push: Not set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...1 = Fin: Set
# 	Expert Info (Chat/Sequence): Connection finish (FIN)
# 	Connection finish (FIN)
# 	Severity level: Chat
# 	Group: Sequence
# 	TCP Flags: ·······A···F
# 	This frame initiates the connection closing
# 	Window: 83
# 	Calculated window size: 83
# 	Window size scaling factor: -1 (unknown)
# 	Checksum: 0xe4d9 [unverified]
# 	Checksum Status: Unverified
# 	Urgent Pointer: 0
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.000000000 seconds
# 	Time since previous frame in this TCP stream: 0.000000000 seconds
# 	Expert Info (Note/Sequence): This frame initiates the connection closing
# 	Severity level: Note
# 	Group: Sequence
#
# ====|cap|=====
# Packet (Length: 54)
# Layer ETH
# :	Destination: 3c:9d:56:e1:2f:c6
# 	Address: 3c:9d:56:e1:2f:c6
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: f8:4d:89:80:34:90
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: f8:4d:89:80:34:90
# Layer IP
# :	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x00 (DSCP: CS0, ECN: Not-ECT)
# 	0000 00.. = Differentiated Services Codepoint: Default (0)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 40
# 	Identification: 0x0000 (0)
# 	010. .... = Flags: 0x2, Don't fragment
# 	0... .... = Reserved bit: Not set
# 	.1.. .... = Don't fragment: Set
# 	..0. .... = More fragments: Not set
# 	...0 0000 0000 0000 = Fragment Offset: 0
# 	Time to Live: 64
# 	Protocol: TCP (6)
# 	Header Checksum: 0x3bde [validation disabled]
# 	Header checksum status: Unverified
# 	Source Address: 192.168.6.104
# 	Destination Address: 111.124.200.101
# Layer TCP
# :	Source Port: 55965
# 	Destination Port: 80
# 	Stream index: 1
# 	Conversation completeness: Incomplete (20)
# 	..0. .... = RST: Absent
# 	...1 .... = FIN: Present
# 	.... 0... = Data: Absent
# 	.... .1.. = ACK: Present
# 	.... ..0. = SYN-ACK: Absent
# 	.... ...0 = SYN: Absent
# 	Completeness Flags: ·F·A··
# 	TCP Segment Len: 0
# 	Sequence Number: 1    (relative sequence number)
# 	Sequence Number (raw): 721421610
# 	Next Sequence Number: 1    (relative sequence number)
# 	Acknowledgment Number: 2    (relative ack number)
# 	Acknowledgment number (raw): 3843808129
# 	0101 .... = Header Length: 20 bytes (5)
# 	Flags: 0x010 (ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Accurate ECN: Not set
# 	.... 0... .... = Congestion Window Reduced: Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 0... = Push: Not set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: ·······A····
# 	Window: 4096
# 	Calculated window size: 4096
# 	Window size scaling factor: -1 (unknown)
# 	Checksum: 0xd52c [unverified]
# 	Checksum Status: Unverified
# 	Urgent Pointer: 0
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.000106000 seconds
# 	Time since previous frame in this TCP stream: 0.000106000 seconds
# 	SEQ/ACK analysis
# 	This is an ACK to the segment in frame: 2
# 	The RTT to ACK the segment was: 0.000106000 seconds
#
# ====|cap|=====
# Packet (Length: 54)
# Layer ETH
# :	Destination: 3c:9d:56:e1:2f:c6
# 	Address: 3c:9d:56:e1:2f:c6
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: f8:4d:89:80:34:90
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: f8:4d:89:80:34:90
# Layer IP
# :	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x00 (DSCP: CS0, ECN: Not-ECT)
# 	0000 00.. = Differentiated Services Codepoint: Default (0)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 40
# 	Identification: 0x0000 (0)
# 	010. .... = Flags: 0x2, Don't fragment
# 	0... .... = Reserved bit: Not set
# 	.1.. .... = Don't fragment: Set
# 	..0. .... = More fragments: Not set
# 	...0 0000 0000 0000 = Fragment Offset: 0
# 	Time to Live: 64
# 	Protocol: TCP (6)
# 	Header Checksum: 0x3bde [validation disabled]
# 	Header checksum status: Unverified
# 	Source Address: 192.168.6.104
# 	Destination Address: 111.124.200.101
# Layer TCP
# :	Source Port: 55965
# 	Destination Port: 80
# 	Stream index: 1
# 	Conversation completeness: Incomplete (20)
# 	..0. .... = RST: Absent
# 	...1 .... = FIN: Present
# 	.... 0... = Data: Absent
# 	.... .1.. = ACK: Present
# 	.... ..0. = SYN-ACK: Absent
# 	.... ...0 = SYN: Absent
# 	Completeness Flags: ·F·A··
# 	TCP Segment Len: 0
# 	Sequence Number: 1    (relative sequence number)
# 	Sequence Number (raw): 721421610
# 	Next Sequence Number: 2    (relative sequence number)
# 	Acknowledgment Number: 2    (relative ack number)
# 	Acknowledgment number (raw): 3843808129
# 	0101 .... = Header Length: 20 bytes (5)
# 	Flags: 0x011 (FIN, ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Accurate ECN: Not set
# 	.... 0... .... = Congestion Window Reduced: Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 0... = Push: Not set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...1 = Fin: Set
# 	Expert Info (Chat/Sequence): Connection finish (FIN)
# 	Connection finish (FIN)
# 	Severity level: Chat
# 	Group: Sequence
# 	TCP Flags: ·······A···F
# 	This frame undergoes the connection closing
# 	Window: 4096
# 	Calculated window size: 4096
# 	Window size scaling factor: -1 (unknown)
# 	Checksum: 0xd52b [unverified]
# 	Checksum Status: Unverified
# 	Urgent Pointer: 0
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.000228000 seconds
# 	Time since previous frame in this TCP stream: 0.000122000 seconds
# 	Expert Info (Note/Sequence): This frame undergoes the connection closing
# 	Severity level: Note
# 	Group: Sequence
#
# ====|cap|=====
# Packet (Length: 60)
# Layer ETH
# :	Destination: f8:4d:89:80:34:90
# 	Address: f8:4d:89:80:34:90
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: 3c:9d:56:e1:2f:c6
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Trailer: 0000c896668d
# 	Expert Info (Note/Protocol): Didn't find padding of zeros, and an undecoded trailer exists. There may be padding of non-zeros.
# 	Didn't find padding of zeros, and an undecoded trailer exists. There may be padding of non-zeros.
# 	Severity level: Note
# 	Group: Protocol
# 	Address: 3c:9d:56:e1:2f:c6
# Layer IP
# :	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x74 (DSCP: Unknown, ECN: Not-ECT)
# 	0111 01.. = Differentiated Services Codepoint: Unknown (29)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 40
# 	Identification: 0x0000 (0)
# 	010. .... = Flags: 0x2, Don't fragment
# 	0... .... = Reserved bit: Not set
# 	.1.. .... = Don't fragment: Set
# 	..0. .... = More fragments: Not set
# 	...0 0000 0000 0000 = Fragment Offset: 0
# 	Time to Live: 43
# 	Protocol: TCP (6)
# 	Header Checksum: 0x506a [validation disabled]
# 	Header checksum status: Unverified
# 	Source Address: 111.124.200.101
# 	Destination Address: 192.168.6.104
# Layer TCP
# :	Source Port: 80
# 	Destination Port: 55965
# 	Stream index: 1
# 	Conversation completeness: Incomplete (20)
# 	..0. .... = RST: Absent
# 	...1 .... = FIN: Present
# 	.... 0... = Data: Absent
# 	.... .1.. = ACK: Present
# 	.... ..0. = SYN-ACK: Absent
# 	.... ...0 = SYN: Absent
# 	Completeness Flags: ·F·A··
# 	TCP Segment Len: 0
# 	Sequence Number: 2    (relative sequence number)
# 	Sequence Number (raw): 3843808129
# 	Next Sequence Number: 2    (relative sequence number)
# 	Acknowledgment Number: 3070525738
# 	Expert Info (Note/Protocol): The acknowledgment number field is nonzero while the ACK flag is not set
# 	The acknowledgment number field is nonzero while the ACK flag is not set
# 	Severity level: Note
# 	Group: Protocol
# 	Acknowledgment number (raw): 3070525738
# 	0101 .... = Header Length: 20 bytes (5)
# 	Flags: 0x004 (RST)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Accurate ECN: Not set
# 	.... 0... .... = Congestion Window Reduced: Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...0 .... = Acknowledgment: Not set
# 	.... .... 0... = Push: Not set
# 	.... .... .1.. = Reset: Set
# 	Connection reset (RST)
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: ·········R··
# 	Window: 0
# 	Calculated window size: 0
# 	Window size scaling factor: -1 (unknown)
# 	Checksum: 0xdd33 [unverified]
# 	Checksum Status: Unverified
# 	Urgent Pointer: 0
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.045314000 seconds
# 	Time since previous frame in this TCP stream: 0.045086000 seconds
# 	Expert Info (Warning/Sequence): Connection reset (RST)
# 	Severity level: Warning
# 	Group: Sequence
#
# ====|cap|=====
# Packet (Length: 66)
# Layer ETH
# :	Destination: f8:4d:89:80:34:90
# 	Address: f8:4d:89:80:34:90
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: 3c:9d:56:e1:2f:c6
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: 3c:9d:56:e1:2f:c6
# Layer IP
# :	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x04 (DSCP: LE, ECN: Not-ECT)
# 	0000 01.. = Differentiated Services Codepoint: Lower Effort (1)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 52
# 	Identification: 0xdd35 (56629)
# 	010. .... = Flags: 0x2, Don't fragment
# 	0... .... = Reserved bit: Not set
# 	.1.. .... = Don't fragment: Set
# 	..0. .... = More fragments: Not set
# 	...0 0000 0000 0000 = Fragment Offset: 0
# 	Time to Live: 18
# 	Protocol: TCP (6)
# 	Header Checksum: 0x10d2 [validation disabled]
# 	Header checksum status: Unverified
# 	Source Address: 36.156.143.12
# 	Destination Address: 192.168.6.104
# Layer TCP
# :	Source Port: 22328
# 	Destination Port: 64342
# 	Stream index: 0
# 	Conversation completeness: Incomplete (8)
# 	..0. .... = RST: Absent
# 	...0 .... = FIN: Absent
# 	.... 1... = Data: Present
# 	.... .0.. = ACK: Absent
# 	.... ..0. = SYN-ACK: Absent
# 	.... ...0 = SYN: Absent
# 	Completeness Flags: ··D···
# 	TCP Segment Len: 0
# 	Sequence Number: 1    (relative sequence number)
# 	Sequence Number (raw): 3727731152
# 	Next Sequence Number: 1    (relative sequence number)
# 	Acknowledgment Number: 250    (relative ack number)
# 	Acknowledgment number (raw): 2854808753
# 	1000 .... = Header Length: 32 bytes (8)
# 	Flags: 0x010 (ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Accurate ECN: Not set
# 	.... 0... .... = Congestion Window Reduced: Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 0... = Push: Not set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: ·······A····
# 	Window: 9
# 	Calculated window size: 9
# 	Window size scaling factor: -1 (unknown)
# 	Checksum: 0x6f1a [unverified]
# 	Checksum Status: Unverified
# 	Urgent Pointer: 0
# 	Options: (12 bytes), No-Operation (NOP), No-Operation (NOP), Timestamps
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	TCP Option - Timestamps: TSval 3920224896, TSecr 861740014
# 	Length: 10
# 	Timestamp value: 3920224896
# 	Timestamp echo reply: 861740014
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.053825000 seconds
# 	Time since previous frame in this TCP stream: 0.053825000 seconds
# 	SEQ/ACK analysis
# 	This is an ACK to the segment in frame: 1
# 	The RTT to ACK the segment was: 0.053825000 seconds
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	Kind: Time Stamp Option (8)
#
# ====|cap|=====
# Packet (Length: 519)
# Layer ETH
# :	Destination: 3c:9d:56:e1:2f:c6
# 	Address: 3c:9d:56:e1:2f:c6
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: f8:4d:89:80:34:90
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: f8:4d:89:80:34:90
# Layer IP
# :	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x00 (DSCP: CS0, ECN: Not-ECT)
# 	0000 00.. = Differentiated Services Codepoint: Default (0)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 505
# 	Identification: 0x0000 (0)
# 	010. .... = Flags: 0x2, Don't fragment
# 	0... .... = Reserved bit: Not set
# 	.1.. .... = Don't fragment: Set
# 	..0. .... = More fragments: Not set
# 	...0 0000 0000 0000 = Fragment Offset: 0
# 	Time to Live: 64
# 	Protocol: TCP (6)
# 	Header Checksum: 0x8fd6 [validation disabled]
# 	Header checksum status: Unverified
# 	Source Address: 192.168.6.104
# 	Destination Address: 36.155.189.125
# Layer TCP
# :	Source Port: 64293
# 	Destination Port: 443
# 	Stream index: 2
# 	Conversation completeness: Incomplete (0)
# 	..0. .... = RST: Absent
# 	...0 .... = FIN: Absent
# 	.... 0... = Data: Absent
# 	.... .0.. = ACK: Absent
# 	.... ..0. = SYN-ACK: Absent
# 	.... ...0 = SYN: Absent
# 	Completeness Flags: [ Null ]
# 	TCP Segment Len: 465
# 	Sequence Number: 1    (relative sequence number)
# 	Sequence Number (raw): 1362973640
# 	Next Sequence Number: 466    (relative sequence number)
# 	Acknowledgment Number: 1    (relative ack number)
# 	Acknowledgment number (raw): 1314081899
# 	0101 .... = Header Length: 20 bytes (5)
# 	Flags: 0x018 (PSH, ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Accurate ECN: Not set
# 	.... 0... .... = Congestion Window Reduced: Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 1... = Push: Set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: ·······AP···
# 	Window: 4096
# 	Calculated window size: 4096
# 	Window size scaling factor: -1 (unknown)
# 	Checksum: 0xde0d [unverified]
# 	Checksum Status: Unverified
# 	Urgent Pointer: 0
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.000000000 seconds
# 	Time since previous frame in this TCP stream: 0.000000000 seconds
# 	SEQ/ACK analysis
# 	Bytes in flight: 465
# 	Bytes sent since last PSH flag: 465
# 	TCP payload (465 bytes)
# Layer TLS
# :
# ====|cap|=====
# Packet (Length: 60)
# Layer ETH
# :	Destination: f8:4d:89:80:34:90
# 	Address: f8:4d:89:80:34:90
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: 3c:9d:56:e1:2f:c6
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Trailer: 000038487212
# 	Expert Info (Note/Protocol): Didn't find padding of zeros, and an undecoded trailer exists. There may be padding of non-zeros.
# 	Didn't find padding of zeros, and an undecoded trailer exists. There may be padding of non-zeros.
# 	Severity level: Note
# 	Group: Protocol
# 	Address: 3c:9d:56:e1:2f:c6
# Layer IP
# :	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x74 (DSCP: Unknown, ECN: Not-ECT)
# 	0111 01.. = Differentiated Services Codepoint: Unknown (29)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 40
# 	Identification: 0xad3e (44350)
# 	010. .... = Flags: 0x2, Don't fragment
# 	0... .... = Reserved bit: Not set
# 	.1.. .... = Don't fragment: Set
# 	..0. .... = More fragments: Not set
# 	...0 0000 0000 0000 = Fragment Offset: 0
# 	Time to Live: 42
# 	Protocol: TCP (6)
# 	Header Checksum: 0xa42b [validation disabled]
# 	Header checksum status: Unverified
# 	Source Address: 111.124.200.101
# 	Destination Address: 192.168.6.104
# Layer TCP
# :	Source Port: 80
# 	Destination Port: 55971
# 	Stream index: 3
# 	Conversation completeness: Incomplete (0)
# 	..0. .... = RST: Absent
# 	...0 .... = FIN: Absent
# 	.... 0... = Data: Absent
# 	.... .0.. = ACK: Absent
# 	.... ..0. = SYN-ACK: Absent
# 	.... ...0 = SYN: Absent
# 	Completeness Flags: [ Null ]
# 	TCP Segment Len: 0
# 	Sequence Number: 1    (relative sequence number)
# 	Sequence Number (raw): 1604970045
# 	Next Sequence Number: 2    (relative sequence number)
# 	Acknowledgment Number: 1    (relative ack number)
# 	Acknowledgment number (raw): 2234444584
# 	0101 .... = Header Length: 20 bytes (5)
# 	Flags: 0x011 (FIN, ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Accurate ECN: Not set
# 	.... 0... .... = Congestion Window Reduced: Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 0... = Push: Not set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...1 = Fin: Set
# 	Expert Info (Chat/Sequence): Connection finish (FIN)
# 	Connection finish (FIN)
# 	Severity level: Chat
# 	Group: Sequence
# 	TCP Flags: ·······A···F
# 	This frame initiates the connection closing
# 	Window: 83
# 	Calculated window size: 83
# 	Window size scaling factor: -1 (unknown)
# 	Checksum: 0x1f5c [unverified]
# 	Checksum Status: Unverified
# 	Urgent Pointer: 0
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.000000000 seconds
# 	Time since previous frame in this TCP stream: 0.000000000 seconds
# 	Expert Info (Note/Sequence): This frame initiates the connection closing
# 	Severity level: Note
# 	Group: Sequence
#
# ====|cap|=====
# Packet (Length: 54)
# Layer ETH
# :	Destination: 3c:9d:56:e1:2f:c6
# 	Address: 3c:9d:56:e1:2f:c6
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: f8:4d:89:80:34:90
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: f8:4d:89:80:34:90
# Layer IP
# :	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x00 (DSCP: CS0, ECN: Not-ECT)
# 	0000 00.. = Differentiated Services Codepoint: Default (0)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 40
# 	Identification: 0x0000 (0)
# 	010. .... = Flags: 0x2, Don't fragment
# 	0... .... = Reserved bit: Not set
# 	.1.. .... = Don't fragment: Set
# 	..0. .... = More fragments: Not set
# 	...0 0000 0000 0000 = Fragment Offset: 0
# 	Time to Live: 64
# 	Protocol: TCP (6)
# 	Header Checksum: 0x3bde [validation disabled]
# 	Header checksum status: Unverified
# 	Source Address: 192.168.6.104
# 	Destination Address: 111.124.200.101
# Layer TCP
# :	Source Port: 55971
# 	Destination Port: 80
# 	Stream index: 3
# 	Conversation completeness: Incomplete (20)
# 	..0. .... = RST: Absent
# 	...1 .... = FIN: Present
# 	.... 0... = Data: Absent
# 	.... .1.. = ACK: Present
# 	.... ..0. = SYN-ACK: Absent
# 	.... ...0 = SYN: Absent
# 	Completeness Flags: ·F·A··
# 	TCP Segment Len: 0
# 	Sequence Number: 1    (relative sequence number)
# 	Sequence Number (raw): 2234444584
# 	Next Sequence Number: 1    (relative sequence number)
# 	Acknowledgment Number: 2    (relative ack number)
# 	Acknowledgment number (raw): 1604970046
# 	0101 .... = Header Length: 20 bytes (5)
# 	Flags: 0x010 (ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Accurate ECN: Not set
# 	.... 0... .... = Congestion Window Reduced: Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 0... = Push: Not set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: ·······A····
# 	Window: 4096
# 	Calculated window size: 4096
# 	Window size scaling factor: -1 (unknown)
# 	Checksum: 0x0faf [unverified]
# 	Checksum Status: Unverified
# 	Urgent Pointer: 0
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.000103000 seconds
# 	Time since previous frame in this TCP stream: 0.000103000 seconds
# 	SEQ/ACK analysis
# 	This is an ACK to the segment in frame: 8
# 	The RTT to ACK the segment was: 0.000103000 seconds
#
# ====|cap|=====
# Packet (Length: 54)
# Layer ETH
# :	Destination: 3c:9d:56:e1:2f:c6
# 	Address: 3c:9d:56:e1:2f:c6
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: f8:4d:89:80:34:90
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: f8:4d:89:80:34:90
# Layer IP
# :	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x00 (DSCP: CS0, ECN: Not-ECT)
# 	0000 00.. = Differentiated Services Codepoint: Default (0)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 40
# 	Identification: 0x0000 (0)
# 	010. .... = Flags: 0x2, Don't fragment
# 	0... .... = Reserved bit: Not set
# 	.1.. .... = Don't fragment: Set
# 	..0. .... = More fragments: Not set
# 	...0 0000 0000 0000 = Fragment Offset: 0
# 	Time to Live: 64
# 	Protocol: TCP (6)
# 	Header Checksum: 0x3bde [validation disabled]
# 	Header checksum status: Unverified
# 	Source Address: 192.168.6.104
# 	Destination Address: 111.124.200.101
# Layer TCP
# :	Source Port: 55971
# 	Destination Port: 80
# 	Stream index: 3
# 	Conversation completeness: Incomplete (20)
# 	..0. .... = RST: Absent
# 	...1 .... = FIN: Present
# 	.... 0... = Data: Absent
# 	.... .1.. = ACK: Present
# 	.... ..0. = SYN-ACK: Absent
# 	.... ...0 = SYN: Absent
# 	Completeness Flags: ·F·A··
# 	TCP Segment Len: 0
# 	Sequence Number: 1    (relative sequence number)
# 	Sequence Number (raw): 2234444584
# 	Next Sequence Number: 2    (relative sequence number)
# 	Acknowledgment Number: 2    (relative ack number)
# 	Acknowledgment number (raw): 1604970046
# 	0101 .... = Header Length: 20 bytes (5)
# 	Flags: 0x011 (FIN, ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Accurate ECN: Not set
# 	.... 0... .... = Congestion Window Reduced: Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 0... = Push: Not set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...1 = Fin: Set
# 	Expert Info (Chat/Sequence): Connection finish (FIN)
# 	Connection finish (FIN)
# 	Severity level: Chat
# 	Group: Sequence
# 	TCP Flags: ·······A···F
# 	This frame undergoes the connection closing
# 	Window: 4096
# 	Calculated window size: 4096
# 	Window size scaling factor: -1 (unknown)
# 	Checksum: 0x0fae [unverified]
# 	Checksum Status: Unverified
# 	Urgent Pointer: 0
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.000311000 seconds
# 	Time since previous frame in this TCP stream: 0.000208000 seconds
# 	Expert Info (Note/Sequence): This frame undergoes the connection closing
# 	Severity level: Note
# 	Group: Sequence
#
# ====|cap|=====
# Packet (Length: 60)
# Layer ETH
# :	Destination: f8:4d:89:80:34:90
# 	Address: f8:4d:89:80:34:90
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: 3c:9d:56:e1:2f:c6
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Padding: 000000000000
# 	Address: 3c:9d:56:e1:2f:c6
# Layer IP
# :	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0xb8 (DSCP: EF PHB, ECN: Not-ECT)
# 	1011 10.. = Differentiated Services Codepoint: Expedited Forwarding (46)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 40
# 	Identification: 0xffb2 (65458)
# 	010. .... = Flags: 0x2, Don't fragment
# 	0... .... = Reserved bit: Not set
# 	.1.. .... = Don't fragment: Set
# 	..0. .... = More fragments: Not set
# 	...0 0000 0000 0000 = Fragment Offset: 0
# 	Time to Live: 47
# 	Protocol: TCP (6)
# 	Header Checksum: 0xa23c [validation disabled]
# 	Header checksum status: Unverified
# 	Source Address: 36.155.189.125
# 	Destination Address: 192.168.6.104
# Layer TCP
# :	Source Port: 443
# 	Destination Port: 64293
# 	Stream index: 2
# 	Conversation completeness: Incomplete (8)
# 	..0. .... = RST: Absent
# 	...0 .... = FIN: Absent
# 	.... 1... = Data: Present
# 	.... .0.. = ACK: Absent
# 	.... ..0. = SYN-ACK: Absent
# 	.... ...0 = SYN: Absent
# 	Completeness Flags: ··D···
# 	TCP Segment Len: 0
# 	Sequence Number: 1    (relative sequence number)
# 	Sequence Number (raw): 1314081899
# 	Next Sequence Number: 1    (relative sequence number)
# 	Acknowledgment Number: 466    (relative ack number)
# 	Acknowledgment number (raw): 1362974105
# 	0101 .... = Header Length: 20 bytes (5)
# 	Flags: 0x010 (ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Accurate ECN: Not set
# 	.... 0... .... = Congestion Window Reduced: Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 0... = Push: Not set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: ·······A····
# 	Window: 330
# 	Calculated window size: 330
# 	Window size scaling factor: -1 (unknown)
# 	Checksum: 0xc6eb [unverified]
# 	Checksum Status: Unverified
# 	Urgent Pointer: 0
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.029752000 seconds
# 	Time since previous frame in this TCP stream: 0.029752000 seconds
# 	SEQ/ACK analysis
# 	This is an ACK to the segment in frame: 7
# 	The RTT to ACK the segment was: 0.029752000 seconds
#
# ====|cap|=====
# Packet (Length: 60)
# Layer ETH
# :	Destination: f8:4d:89:80:34:90
# 	Address: f8:4d:89:80:34:90
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: 3c:9d:56:e1:2f:c6
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Trailer: 0000bd0a1ee9
# 	Expert Info (Note/Protocol): Didn't find padding of zeros, and an undecoded trailer exists. There may be padding of non-zeros.
# 	Didn't find padding of zeros, and an undecoded trailer exists. There may be padding of non-zeros.
# 	Severity level: Note
# 	Group: Protocol
# 	Address: 3c:9d:56:e1:2f:c6
# Layer IP
# :	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x74 (DSCP: Unknown, ECN: Not-ECT)
# 	0111 01.. = Differentiated Services Codepoint: Unknown (29)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 40
# 	Identification: 0x0000 (0)
# 	010. .... = Flags: 0x2, Don't fragment
# 	0... .... = Reserved bit: Not set
# 	.1.. .... = Don't fragment: Set
# 	..0. .... = More fragments: Not set
# 	...0 0000 0000 0000 = Fragment Offset: 0
# 	Time to Live: 42
# 	Protocol: TCP (6)
# 	Header Checksum: 0x516a [validation disabled]
# 	Header checksum status: Unverified
# 	Source Address: 111.124.200.101
# 	Destination Address: 192.168.6.104
# Layer TCP
# :	Source Port: 80
# 	Destination Port: 55971
# 	Stream index: 3
# 	Conversation completeness: Incomplete (20)
# 	..0. .... = RST: Absent
# 	...1 .... = FIN: Present
# 	.... 0... = Data: Absent
# 	.... .1.. = ACK: Present
# 	.... ..0. = SYN-ACK: Absent
# 	.... ...0 = SYN: Absent
# 	Completeness Flags: ·F·A··
# 	TCP Segment Len: 0
# 	Sequence Number: 2    (relative sequence number)
# 	Sequence Number (raw): 1604970046
# 	Next Sequence Number: 2    (relative sequence number)
# 	Acknowledgment Number: 2504239140
# 	Expert Info (Note/Protocol): The acknowledgment number field is nonzero while the ACK flag is not set
# 	The acknowledgment number field is nonzero while the ACK flag is not set
# 	Severity level: Note
# 	Group: Protocol
# 	Acknowledgment number (raw): 2504239140
# 	0101 .... = Header Length: 20 bytes (5)
# 	Flags: 0x004 (RST)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Accurate ECN: Not set
# 	.... 0... .... = Congestion Window Reduced: Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...0 .... = Acknowledgment: Not set
# 	.... .... 0... = Push: Not set
# 	.... .... .1.. = Reset: Set
# 	Connection reset (RST)
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: ·········R··
# 	Window: 0
# 	Calculated window size: 0
# 	Window size scaling factor: -1 (unknown)
# 	Checksum: 0x52aa [unverified]
# 	Checksum Status: Unverified
# 	Urgent Pointer: 0
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.042703000 seconds
# 	Time since previous frame in this TCP stream: 0.042392000 seconds
# 	Expert Info (Warning/Sequence): Connection reset (RST)
# 	Severity level: Warning
# 	Group: Sequence
#
# ====|cap|=====
# Packet (Length: 147)
# Layer ETH
# :	Destination: f8:4d:89:80:34:90
# 	Address: f8:4d:89:80:34:90
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: 3c:9d:56:e1:2f:c6
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: 3c:9d:56:e1:2f:c6
# Layer IP
# :	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0xb8 (DSCP: EF PHB, ECN: Not-ECT)
# 	1011 10.. = Differentiated Services Codepoint: Expedited Forwarding (46)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 133
# 	Identification: 0xffb3 (65459)
# 	010. .... = Flags: 0x2, Don't fragment
# 	0... .... = Reserved bit: Not set
# 	.1.. .... = Don't fragment: Set
# 	..0. .... = More fragments: Not set
# 	...0 0000 0000 0000 = Fragment Offset: 0
# 	Time to Live: 47
# 	Protocol: TCP (6)
# 	Header Checksum: 0xa1de [validation disabled]
# 	Header checksum status: Unverified
# 	Source Address: 36.155.189.125
# 	Destination Address: 192.168.6.104
# Layer TCP
# :	Source Port: 443
# 	Destination Port: 64293
# 	Stream index: 2
# 	Conversation completeness: Incomplete (12)
# 	..0. .... = RST: Absent
# 	...0 .... = FIN: Absent
# 	.... 1... = Data: Present
# 	.... .1.. = ACK: Present
# 	.... ..0. = SYN-ACK: Absent
# 	.... ...0 = SYN: Absent
# 	Completeness Flags: ··DA··
# 	TCP Segment Len: 93
# 	Sequence Number: 1    (relative sequence number)
# 	Sequence Number (raw): 1314081899
# 	Next Sequence Number: 94    (relative sequence number)
# 	Acknowledgment Number: 466    (relative ack number)
# 	Acknowledgment number (raw): 1362974105
# 	0101 .... = Header Length: 20 bytes (5)
# 	Flags: 0x018 (PSH, ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Accurate ECN: Not set
# 	.... 0... .... = Congestion Window Reduced: Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 1... = Push: Set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: ·······AP···
# 	Window: 330
# 	Calculated window size: 330
# 	Window size scaling factor: -1 (unknown)
# 	Checksum: 0xc8be [unverified]
# 	Checksum Status: Unverified
# 	Urgent Pointer: 0
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.062861000 seconds
# 	Time since previous frame in this TCP stream: 0.033109000 seconds
# 	SEQ/ACK analysis
# 	Bytes in flight: 93
# 	Bytes sent since last PSH flag: 93
# 	TCP payload (93 bytes)
# Layer TLS
# :
# ====|cap|=====
# Packet (Length: 54)
# Layer ETH
# :	Destination: 3c:9d:56:e1:2f:c6
# 	Address: 3c:9d:56:e1:2f:c6
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: f8:4d:89:80:34:90
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: f8:4d:89:80:34:90
# Layer IP
# :	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x00 (DSCP: CS0, ECN: Not-ECT)
# 	0000 00.. = Differentiated Services Codepoint: Default (0)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 40
# 	Identification: 0x0000 (0)
# 	010. .... = Flags: 0x2, Don't fragment
# 	0... .... = Reserved bit: Not set
# 	.1.. .... = Don't fragment: Set
# 	..0. .... = More fragments: Not set
# 	...0 0000 0000 0000 = Fragment Offset: 0
# 	Time to Live: 64
# 	Protocol: TCP (6)
# 	Header Checksum: 0x91a7 [validation disabled]
# 	Header checksum status: Unverified
# 	Source Address: 192.168.6.104
# 	Destination Address: 36.155.189.125
# Layer TCP
# :	Source Port: 64293
# 	Destination Port: 443
# 	Stream index: 2
# 	Conversation completeness: Incomplete (12)
# 	..0. .... = RST: Absent
# 	...0 .... = FIN: Absent
# 	.... 1... = Data: Present
# 	.... .1.. = ACK: Present
# 	.... ..0. = SYN-ACK: Absent
# 	.... ...0 = SYN: Absent
# 	Completeness Flags: ··DA··
# 	TCP Segment Len: 0
# 	Sequence Number: 466    (relative sequence number)
# 	Sequence Number (raw): 1362974105
# 	Next Sequence Number: 466    (relative sequence number)
# 	Acknowledgment Number: 94    (relative ack number)
# 	Acknowledgment number (raw): 1314081992
# 	0101 .... = Header Length: 20 bytes (5)
# 	Flags: 0x010 (ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Accurate ECN: Not set
# 	.... 0... .... = Congestion Window Reduced: Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 0... = Push: Not set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: ·······A····
# 	Window: 4094
# 	Calculated window size: 4094
# 	Window size scaling factor: -1 (unknown)
# 	Checksum: 0xb7da [unverified]
# 	Checksum Status: Unverified
# 	Urgent Pointer: 0
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.063009000 seconds
# 	Time since previous frame in this TCP stream: 0.000148000 seconds
# 	SEQ/ACK analysis
# 	This is an ACK to the segment in frame: 13
# 	The RTT to ACK the segment was: 0.000148000 seconds
#
# ====|cap|=====
# Packet (Length: 78)
# Layer ETH
# :	Destination: f8:4d:89:80:34:90
# 	Address: f8:4d:89:80:34:90
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: 3c:9d:56:e1:2f:c6
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: 3c:9d:56:e1:2f:c6
# Layer IP
# :	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x74 (DSCP: Unknown, ECN: Not-ECT)
# 	0111 01.. = Differentiated Services Codepoint: Unknown (29)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 64
# 	Identification: 0x5ea5 (24229)
# 	010. .... = Flags: 0x2, Don't fragment
# 	0... .... = Reserved bit: Not set
# 	.1.. .... = Don't fragment: Set
# 	..0. .... = More fragments: Not set
# 	...0 0000 0000 0000 = Fragment Offset: 0
# 	Time to Live: 43
# 	Protocol: TCP (6)
# 	Header Checksum: 0xf1ac [validation disabled]
# 	Header checksum status: Unverified
# 	Source Address: 111.124.200.101
# 	Destination Address: 192.168.6.104
# Layer TCP
# :	Source Port: 443
# 	Destination Port: 55973
# 	Stream index: 4
# 	Conversation completeness: Incomplete (0)
# 	..0. .... = RST: Absent
# 	...0 .... = FIN: Absent
# 	.... 0... = Data: Absent
# 	.... .0.. = ACK: Absent
# 	.... ..0. = SYN-ACK: Absent
# 	.... ...0 = SYN: Absent
# 	Completeness Flags: [ Null ]
# 	TCP Segment Len: 24
# 	Sequence Number: 1    (relative sequence number)
# 	Sequence Number (raw): 2227654896
# 	Next Sequence Number: 25    (relative sequence number)
# 	Acknowledgment Number: 1    (relative ack number)
# 	Acknowledgment number (raw): 2375595101
# 	0101 .... = Header Length: 20 bytes (5)
# 	Flags: 0x018 (PSH, ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Accurate ECN: Not set
# 	.... 0... .... = Congestion Window Reduced: Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 1... = Push: Set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: ·······AP···
# 	Window: 83
# 	Calculated window size: 83
# 	Window size scaling factor: -1 (unknown)
# 	Checksum: 0x92e3 [unverified]
# 	Checksum Status: Unverified
# 	Urgent Pointer: 0
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.000000000 seconds
# 	Time since previous frame in this TCP stream: 0.000000000 seconds
# 	SEQ/ACK analysis
# 	Bytes in flight: 24
# 	Bytes sent since last PSH flag: 24
# 	TCP payload (24 bytes)
# Layer TLS
# :	TLSv1.2 Record Layer: Application Data Protocol: Hypertext Transfer Protocol
# 	Content Type: Application Data (23)
# 	Version: TLS 1.2 (0x0303)
# 	Length: 19
# 	Encrypted Application Data: b0356919680c8d90963d15780ff938b9b3a7c3
# 	Application Data Protocol: Hypertext Transfer Protocol
#
# ====|cap|=====
# Packet (Length: 60)
# Layer ETH
# :	Destination: f8:4d:89:80:34:90
# 	Address: f8:4d:89:80:34:90
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: 3c:9d:56:e1:2f:c6
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Trailer: 0000499320f6
# 	Expert Info (Note/Protocol): Didn't find padding of zeros, and an undecoded trailer exists. There may be padding of non-zeros.
# 	Didn't find padding of zeros, and an undecoded trailer exists. There may be padding of non-zeros.
# 	Severity level: Note
# 	Group: Protocol
# 	Address: 3c:9d:56:e1:2f:c6
# Layer IP
# :	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x74 (DSCP: Unknown, ECN: Not-ECT)
# 	0111 01.. = Differentiated Services Codepoint: Unknown (29)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 40
# 	Identification: 0x5ea6 (24230)
# 	010. .... = Flags: 0x2, Don't fragment
# 	0... .... = Reserved bit: Not set
# 	.1.. .... = Don't fragment: Set
# 	..0. .... = More fragments: Not set
# 	...0 0000 0000 0000 = Fragment Offset: 0
# 	Time to Live: 43
# 	Protocol: TCP (6)
# 	Header Checksum: 0xf1c3 [validation disabled]
# 	Header checksum status: Unverified
# 	Source Address: 111.124.200.101
# 	Destination Address: 192.168.6.104
# Layer TCP
# :	Source Port: 443
# 	Destination Port: 55973
# 	Stream index: 4
# 	Conversation completeness: Incomplete (8)
# 	..0. .... = RST: Absent
# 	...0 .... = FIN: Absent
# 	.... 1... = Data: Present
# 	.... .0.. = ACK: Absent
# 	.... ..0. = SYN-ACK: Absent
# 	.... ...0 = SYN: Absent
# 	Completeness Flags: ··D···
# 	TCP Segment Len: 0
# 	Sequence Number: 25    (relative sequence number)
# 	Sequence Number (raw): 2227654920
# 	Next Sequence Number: 26    (relative sequence number)
# 	Acknowledgment Number: 1    (relative ack number)
# 	Acknowledgment number (raw): 2375595101
# 	0101 .... = Header Length: 20 bytes (5)
# 	Flags: 0x011 (FIN, ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Accurate ECN: Not set
# 	.... 0... .... = Congestion Window Reduced: Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 0... = Push: Not set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...1 = Fin: Set
# 	Expert Info (Chat/Sequence): Connection finish (FIN)
# 	Connection finish (FIN)
# 	Severity level: Chat
# 	Group: Sequence
# 	TCP Flags: ·······A···F
# 	This frame initiates the connection closing
# 	Window: 83
# 	Calculated window size: 83
# 	Window size scaling factor: -1 (unknown)
# 	Checksum: 0xbc67 [unverified]
# 	Checksum Status: Unverified
# 	Urgent Pointer: 0
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.000002000 seconds
# 	Time since previous frame in this TCP stream: 0.000002000 seconds
# 	Expert Info (Note/Sequence): This frame initiates the connection closing
# 	Severity level: Note
# 	Group: Sequence
#
# ====|cap|=====
# Packet (Length: 54)
# Layer ETH
# :	Destination: 3c:9d:56:e1:2f:c6
# 	Address: 3c:9d:56:e1:2f:c6
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: f8:4d:89:80:34:90
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: f8:4d:89:80:34:90
# Layer IP
# :	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x00 (DSCP: CS0, ECN: Not-ECT)
# 	0000 00.. = Differentiated Services Codepoint: Default (0)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 40
# 	Identification: 0x0000 (0)
# 	010. .... = Flags: 0x2, Don't fragment
# 	0... .... = Reserved bit: Not set
# 	.1.. .... = Don't fragment: Set
# 	..0. .... = More fragments: Not set
# 	...0 0000 0000 0000 = Fragment Offset: 0
# 	Time to Live: 64
# 	Protocol: TCP (6)
# 	Header Checksum: 0x3bde [validation disabled]
# 	Header checksum status: Unverified
# 	Source Address: 192.168.6.104
# 	Destination Address: 111.124.200.101
# Layer TCP
# :	Source Port: 55973
# 	Destination Port: 443
# 	Stream index: 4
# 	Conversation completeness: Incomplete (28)
# 	..0. .... = RST: Absent
# 	...1 .... = FIN: Present
# 	.... 1... = Data: Present
# 	.... .1.. = ACK: Present
# 	.... ..0. = SYN-ACK: Absent
# 	.... ...0 = SYN: Absent
# 	Completeness Flags: ·FDA··
# 	TCP Segment Len: 0
# 	Sequence Number: 1    (relative sequence number)
# 	Sequence Number (raw): 2375595101
# 	Next Sequence Number: 1    (relative sequence number)
# 	Acknowledgment Number: 25    (relative ack number)
# 	Acknowledgment number (raw): 2227654920
# 	0101 .... = Header Length: 20 bytes (5)
# 	Flags: 0x010 (ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Accurate ECN: Not set
# 	.... 0... .... = Congestion Window Reduced: Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 0... = Push: Not set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: ·······A····
# 	Window: 4095
# 	Calculated window size: 4095
# 	Window size scaling factor: -1 (unknown)
# 	Checksum: 0xacbc [unverified]
# 	Checksum Status: Unverified
# 	Urgent Pointer: 0
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.000162000 seconds
# 	Time since previous frame in this TCP stream: 0.000160000 seconds
# ...
# 	.1.. .... = Don't fragment: Set
# 	..0. .... = More fragments: Not set
# 	...0 0000 0000 0000 = Fragment Offset: 0
# 	Time to Live: 46
# 	Protocol: TCP (6)
# 	Header Checksum: 0xd2a8 [validation disabled]
# 	Header checksum status: Unverified
# 	Source Address: 1.0.0.1
# 	Destination Address: 192.168.6.104
# Layer TCP
# :	Source Port: 443
# 	Destination Port: 64470
# 	Stream index: 13
# 	Conversation completeness: Incomplete (12)
# 	..0. .... = RST: Absent
# 	...0 .... = FIN: Absent
# 	.... 1... = Data: Present
# 	.... .1.. = ACK: Present
# 	.... ..0. = SYN-ACK: Absent
# 	.... ...0 = SYN: Absent
# 	Completeness Flags: ··DA··
# 	TCP Segment Len: 0
# 	Sequence Number: 285    (relative sequence number)
# 	Sequence Number (raw): 3445626253
# 	Next Sequence Number: 285    (relative sequence number)
# 	Acknowledgment Number: 156    (relative ack number)
# 	Acknowledgment number (raw): 315099186
# 	1000 .... = Header Length: 32 bytes (8)
# 	Flags: 0x010 (ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Accurate ECN: Not set
# 	.... 0... .... = Congestion Window Reduced: Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 0... = Push: Not set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: ·······A····
# 	Window: 60
# 	Calculated window size: 60
# 	Window size scaling factor: -1 (unknown)
# 	Checksum: 0x4dfc [unverified]
# 	Checksum Status: Unverified
# 	Urgent Pointer: 0
# 	Options: (12 bytes), No-Operation (NOP), No-Operation (NOP), Timestamps
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	TCP Option - Timestamps: TSval 2865317996, TSecr 550457589
# 	Length: 10
# 	Timestamp value: 2865317996
# 	Timestamp echo reply: 550457589
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.245711000 seconds
# 	Time since previous frame in this TCP stream: 0.045867000 seconds
# 	SEQ/ACK analysis
# 	This is an ACK to the segment in frame: 68
# 	The RTT to ACK the segment was: 0.235170000 seconds
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	Kind: Time Stamp Option (8)
#
# ====|cap|=====
# Packet (Length: 78)
# Layer ETH
# :	Destination: f8:4d:89:80:34:90
# 	Address: f8:4d:89:80:34:90
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: 3c:9d:56:e1:2f:c6
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: 3c:9d:56:e1:2f:c6
# Layer IP
# :	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x74 (DSCP: Unknown, ECN: Not-ECT)
# 	0111 01.. = Differentiated Services Codepoint: Unknown (29)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 64
# 	Identification: 0xb198 (45464)
# 	010. .... = Flags: 0x2, Don't fragment
# 	0... .... = Reserved bit: Not set
# 	.1.. .... = Don't fragment: Set
# 	..0. .... = More fragments: Not set
# 	...0 0000 0000 0000 = Fragment Offset: 0
# 	Time to Live: 46
# 	Protocol: TCP (6)
# 	Header Checksum: 0xd29a [validation disabled]
# 	Header checksum status: Unverified
# 	Source Address: 1.0.0.1
# 	Destination Address: 192.168.6.104
# Layer TCP
# :	Source Port: 443
# 	Destination Port: 64470
# 	Stream index: 13
# 	Conversation completeness: Incomplete (12)
# 	..0. .... = RST: Absent
# 	...0 .... = FIN: Absent
# 	.... 1... = Data: Present
# 	.... .1.. = ACK: Present
# 	.... ..0. = SYN-ACK: Absent
# 	.... ...0 = SYN: Absent
# 	Completeness Flags: ··DA··
# 	TCP Segment Len: 0
# 	Sequence Number: 285    (relative sequence number)
# 	Sequence Number (raw): 3445626253
# 	Next Sequence Number: 285    (relative sequence number)
# 	Acknowledgment Number: 156    (relative ack number)
# 	Acknowledgment number (raw): 315099186
# 	1011 .... = Header Length: 44 bytes (11)
# 	Flags: 0x010 (ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Accurate ECN: Not set
# 	.... 0... .... = Congestion Window Reduced: Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 0... = Push: Not set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: ·······A····
# 	Window: 60
# 	Calculated window size: 60
# 	Window size scaling factor: -1 (unknown)
# 	Checksum: 0xe1ad [unverified]
# 	Checksum Status: Unverified
# 	Urgent Pointer: 0
# 	Options: (24 bytes), No-Operation (NOP), No-Operation (NOP), Timestamps, No-Operation (NOP), No-Operation (NOP), SACK
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	TCP Option - Timestamps: TSval 2865318144, TSecr 550457778
# 	Length: 10
# 	Timestamp value: 2865318144
# 	Timestamp echo reply: 550457778
# 	TCP Option - SACK 1-41
# 	left edge = 1 (relative)
# 	right edge = 41 (relative)
# 	TCP SACK Count: 1
# 	D-SACK Left Edge = 1 (relative)
# 	D-SACK Right Edge = 41 (relative)
# 	D-SACK Sequence
# 	Expert Info (Warning/Sequence): D-SACK Sequence
# 	D-SACK Sequence
# 	Severity level: Warning
# 	Group: Sequence
# 	Time since first frame in this TCP stream: 0.408398000 seconds
# 	Time since previous frame in this TCP stream: 0.162687000 seconds
# 	SEQ/ACK analysis
# 	TCP Analysis Flags
# 	This is a TCP duplicate ack
# 	Duplicate ACK #: 1
# 	Duplicate to the ACK in frame: 108
# 	TCP Option - No-Operation (NOP)
# 	TCP Option - No-Operation (NOP)
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	Kind: Time Stamp Option (8)
# 	Kind: No-Operation (1)
# 	Kind: No-Operation (1)
# 	Kind: SACK (5)
# 	Length: 10
# 	Timestamps
# 	Expert Info (Note/Sequence): Duplicate ACK (#1)
# 	Severity level: Note
# 	Group: Sequence
# 	Duplicate ACK (#1)
#
# ====|cap|=====
# Packet (Length: 78)
# Layer ETH
# :	Destination: f8:4d:89:80:34:90
# 	Address: f8:4d:89:80:34:90
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: 3c:9d:56:e1:2f:c6
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: 3c:9d:56:e1:2f:c6
# Layer IP
# :	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x74 (DSCP: Unknown, ECN: Not-ECT)
# 	0111 01.. = Differentiated Services Codepoint: Unknown (29)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 64
# 	Identification: 0xb197 (45463)
# 	010. .... = Flags: 0x2, Don't fragment
# 	0... .... = Reserved bit: Not set
# 	.1.. .... = Don't fragment: Set
# 	..0. .... = More fragments: Not set
# 	...0 0000 0000 0000 = Fragment Offset: 0
# 	Time to Live: 46
# 	Protocol: TCP (6)
# 	Header Checksum: 0xd29b [validation disabled]
# 	Header checksum status: Unverified
# 	Source Address: 1.0.0.1
# 	Destination Address: 192.168.6.104
# Layer TCP
# :	Source Port: 443
# 	Destination Port: 64470
# 	Stream index: 13
# 	Conversation completeness: Incomplete (12)
# 	..0. .... = RST: Absent
# 	...0 .... = FIN: Absent
# 	.... 1... = Data: Present
# 	.... .1.. = ACK: Present
# 	.... ..0. = SYN-ACK: Absent
# 	.... ...0 = SYN: Absent
# 	Completeness Flags: ··DA··
# 	TCP Segment Len: 0
# 	Sequence Number: 285    (relative sequence number)
# 	Sequence Number (raw): 3445626253
# 	Next Sequence Number: 285    (relative sequence number)
# 	Acknowledgment Number: 156    (relative ack number)
# 	Acknowledgment number (raw): 315099186
# 	1011 .... = Header Length: 44 bytes (11)
# 	Flags: 0x010 (ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Accurate ECN: Not set
# 	.... 0... .... = Congestion Window Reduced: Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 0... = Push: Not set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: ·······A····
# 	Window: 60
# 	Calculated window size: 60
# 	Window size scaling factor: -1 (unknown)
# 	Checksum: 0xe0c3 [unverified]
# 	Checksum Status: Unverified
# 	Urgent Pointer: 0
# 	Options: (24 bytes), No-Operation (NOP), No-Operation (NOP), Timestamps, No-Operation (NOP), No-Operation (NOP), SACK
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	TCP Option - Timestamps: TSval 2865318143, TSecr 550457778
# 	Length: 10
# 	Timestamp value: 2865318143
# 	Timestamp echo reply: 550457778
# 	TCP Option - SACK 121-156
# 	left edge = 121 (relative)
# 	right edge = 156 (relative)
# 	TCP SACK Count: 1
# 	D-SACK Left Edge = 121 (relative)
# 	D-SACK Right Edge = 156 (relative)
# 	D-SACK Sequence
# 	Expert Info (Warning/Sequence): D-SACK Sequence
# 	D-SACK Sequence
# 	Severity level: Warning
# 	Group: Sequence
# 	Time since first frame in this TCP stream: 0.408402000 seconds
# 	Time since previous frame in this TCP stream: 0.000004000 seconds
# 	SEQ/ACK analysis
# 	TCP Analysis Flags
# 	This is a TCP duplicate ack
# 	Duplicate ACK #: 2
# 	Duplicate to the ACK in frame: 108
# 	TCP Option - No-Operation (NOP)
# 	TCP Option - No-Operation (NOP)
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	Kind: Time Stamp Option (8)
# 	Kind: No-Operation (1)
# 	Kind: No-Operation (1)
# 	Kind: SACK (5)
# 	Length: 10
# 	Timestamps
# 	Expert Info (Note/Sequence): Duplicate ACK (#2)
# 	Severity level: Note
# 	Group: Sequence
# 	Duplicate ACK (#2)
#
# ====|cap|=====
# Packet (Length: 78)
# Layer ETH
# :	Destination: f8:4d:89:80:34:90
# 	Address: f8:4d:89:80:34:90
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: 3c:9d:56:e1:2f:c6
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: 3c:9d:56:e1:2f:c6
# Layer IP
# :	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x74 (DSCP: Unknown, ECN: Not-ECT)
# 	0111 01.. = Differentiated Services Codepoint: Unknown (29)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 64
# 	Identification: 0xb199 (45465)
# 	010. .... = Flags: 0x2, Don't fragment
# 	0... .... = Reserved bit: Not set
# 	.1.. .... = Don't fragment: Set
# 	..0. .... = More fragments: Not set
# 	...0 0000 0000 0000 = Fragment Offset: 0
# 	Time to Live: 46
# 	Protocol: TCP (6)
# 	Header Checksum: 0xd299 [validation disabled]
# 	Header checksum status: Unverified
# 	Source Address: 1.0.0.1
# 	Destination Address: 192.168.6.104
# Layer TCP
# :	Source Port: 443
# 	Destination Port: 64470
# 	Stream index: 13
# 	Conversation completeness: Incomplete (12)
# 	..0. .... = RST: Absent
# 	...0 .... = FIN: Absent
# 	.... 1... = Data: Present
# 	.... .1.. = ACK: Present
# 	.... ..0. = SYN-ACK: Absent
# 	.... ...0 = SYN: Absent
# 	Completeness Flags: ··DA··
# 	TCP Segment Len: 0
# 	Sequence Number: 285    (relative sequence number)
# 	Sequence Number (raw): 3445626253
# 	Next Sequence Number: 285    (relative sequence number)
# 	Acknowledgment Number: 156    (relative ack number)
# 	Acknowledgment number (raw): 315099186
# 	1011 .... = Header Length: 44 bytes (11)
# 	Flags: 0x010 (ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Accurate ECN: Not set
# 	.... 0... .... = Congestion Window Reduced: Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 0... = Push: Not set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: ·······A····
# 	Window: 60
# 	Calculated window size: 60
# 	Window size scaling factor: -1 (unknown)
# 	Checksum: 0xe0c2 [unverified]
# 	Checksum Status: Unverified
# 	Urgent Pointer: 0
# 	Options: (24 bytes), No-Operation (NOP), No-Operation (NOP), Timestamps, No-Operation (NOP), No-Operation (NOP), SACK
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	TCP Option - Timestamps: TSval 2865318144, TSecr 550457778
# 	Length: 10
# 	Timestamp value: 2865318144
# 	Timestamp echo reply: 550457778
# 	TCP Option - SACK 121-156
# 	left edge = 121 (relative)
# 	right edge = 156 (relative)
# 	TCP SACK Count: 1
# 	D-SACK Left Edge = 121 (relative)
# 	D-SACK Right Edge = 156 (relative)
# 	D-SACK Sequence
# 	Expert Info (Warning/Sequence): D-SACK Sequence
# 	D-SACK Sequence
# 	Severity level: Warning
# 	Group: Sequence
# 	Time since first frame in this TCP stream: 0.408403000 seconds
# 	Time since previous frame in this TCP stream: 0.000001000 seconds
# 	SEQ/ACK analysis
# 	TCP Analysis Flags
# 	This is a TCP duplicate ack
# 	Duplicate ACK #: 3
# 	Duplicate to the ACK in frame: 108
# 	TCP Option - No-Operation (NOP)
# 	TCP Option - No-Operation (NOP)
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	Kind: Time Stamp Option (8)
# 	Kind: No-Operation (1)
# 	Kind: No-Operation (1)
# 	Kind: SACK (5)
# 	Length: 10
# 	Timestamps
# 	Expert Info (Note/Sequence): Duplicate ACK (#3)
# 	Severity level: Note
# 	Group: Sequence
# 	Duplicate ACK (#3)
#
# ====|cap|=====
# Packet (Length: 195)
# Layer ETH
# :	Destination: f8:4d:89:80:34:90
# 	Address: f8:4d:89:80:34:90
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: 3c:9d:56:e1:2f:c6
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: 3c:9d:56:e1:2f:c6
# Layer IP
# :	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x04 (DSCP: LE, ECN: Not-ECT)
# 	0000 01.. = Differentiated Services Codepoint: Lower Effort (1)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 181
# 	Identification: 0xa254 (41556)
# 	010. .... = Flags: 0x2, Don't fragment
# 	0... .... = Reserved bit: Not set
# 	.1.. .... = Don't fragment: Set
# 	..0. .... = More fragments: Not set
# 	...0 0000 0000 0000 = Fragment Offset: 0
# 	Time to Live: 19
# 	Protocol: TCP (6)
# 	Header Checksum: 0xddf7 [validation disabled]
# 	Header checksum status: Unverified
# 	Source Address: 36.139.251.87
# 	Destination Address: 192.168.6.104
# Layer TCP
# :	Source Port: 22328
# 	Destination Port: 49413
# 	Stream index: 8
# 	Conversation completeness: Incomplete (12)
# 	..0. .... = RST: Absent
# 	...0 .... = FIN: Absent
# 	.... 1... = Data: Present
# 	.... .1.. = ACK: Present
# 	.... ..0. = SYN-ACK: Absent
# 	.... ...0 = SYN: Absent
# 	Completeness Flags: ··DA··
# 	TCP Segment Len: 129
# 	Sequence Number: 1    (relative sequence number)
# 	Sequence Number (raw): 3547956454
# 	Next Sequence Number: 130    (relative sequence number)
# 	Acknowledgment Number: 107    (relative ack number)
# 	Acknowledgment number (raw): 4169133643
# 	1000 .... = Header Length: 32 bytes (8)
# 	Flags: 0x018 (PSH, ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Accurate ECN: Not set
# 	.... 0... .... = Congestion Window Reduced: Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 1... = Push: Set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: ·······AP···
# 	Window: 2
# 	Calculated window size: 2
# 	Window size scaling factor: -1 (unknown)
# 	Checksum: 0xf2e0 [unverified]
# 	Checksum Status: Unverified
# 	Urgent Pointer: 0
# 	Options: (12 bytes), No-Operation (NOP), No-Operation (NOP), Timestamps
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	TCP Option - Timestamps: TSval 608745002, TSecr 3563023130
# 	Length: 10
# 	Timestamp value: 608745002
# 	Timestamp echo reply: 3563023130
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.589349000 seconds
# 	Time since previous frame in this TCP stream: 0.539678000 seconds
# 	SEQ/ACK analysis
# 	Bytes in flight: 129
# 	Bytes sent since last PSH flag: 129
# 	TCP payload (129 bytes)
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	Kind: Time Stamp Option (8)
# DATA
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 13
#      11 print('====|cap|=====')
#      12 print(packet)
# ---> 13 time.sleep(0.1)
#
# KeyboardInterrupt:

# %%
import pyshark
import time
# 使用过滤器捕获 HTTP 流量
capture = pyshark.LiveCapture(interface='Wi-Fi', display_filter='http')

# 捕获流量，设置超时时间为50秒
capture.sniff(timeout=5)

# 打印捕获到的 HTTP 数据包
print('start')
for packet in capture:
    print(packet)
    # print('Packet Number:', packet.number)
    # print('Timestamp:', packet.sniff_time)
    # print('Source IP:', packet.ip.src)
    # print('Destination IP:', packet.ip.dst)
    time.sleep(0.1)
# Out:
# start
# Packet (Length: 148)
# Layer ETH
# :	Destination: 3c:9d:56:e1:2f:c6
# 	Address: 3c:9d:56:e1:2f:c6
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: f8:4d:89:80:34:90
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: f8:4d:89:80:34:90
# Layer IP
# :	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x00 (DSCP: CS0, ECN: Not-ECT)
# 	0000 00.. = Differentiated Services Codepoint: Default (0)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 134
# 	Identification: 0x0000 (0)
# 	010. .... = Flags: 0x2, Don't fragment
# 	0... .... = Reserved bit: Not set
# 	.1.. .... = Don't fragment: Set
# 	..0. .... = More fragments: Not set
# 	...0 0000 0000 0000 = Fragment Offset: 0
# 	Time to Live: 64
# 	Protocol: TCP (6)
# 	Header Checksum: 0xaa3c [validation disabled]
# 	Header checksum status: Unverified
# 	Source Address: 192.168.6.104
# 	Destination Address: 192.168.8.125
# Layer TCP
# :	Source Port: 55392
# 	Destination Port: 11435
# 	Stream index: 5
# 	Conversation completeness: Incomplete, ESTABLISHED (7)
# 	..0. .... = RST: Absent
# 	...0 .... = FIN: Absent
# 	.... 0... = Data: Absent
# 	.... .1.. = ACK: Present
# 	.... ..1. = SYN-ACK: Present
# 	.... ...1 = SYN: Present
# 	Completeness Flags: ···ASS
# 	TCP Segment Len: 82
# 	Sequence Number: 1    (relative sequence number)
# 	Sequence Number (raw): 2950180023
# 	Next Sequence Number: 83    (relative sequence number)
# 	Acknowledgment Number: 1    (relative ack number)
# 	Acknowledgment number (raw): 4162746490
# 	1000 .... = Header Length: 32 bytes (8)
# 	Flags: 0x018 (PSH, ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Accurate ECN: Not set
# 	.... 0... .... = Congestion Window Reduced: Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 1... = Push: Set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: ·······AP···
# 	Window: 2058
# 	Calculated window size: 131712
# 	Window size scaling factor: 64
# 	Checksum: 0x517e [unverified]
# 	Checksum Status: Unverified
# 	Urgent Pointer: 0
# 	Options: (12 bytes), No-Operation (NOP), No-Operation (NOP), Timestamps
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	TCP Option - Timestamps: TSval 3384971114, TSecr 1714442625
# 	Length: 10
# 	Timestamp value: 3384971114
# 	Timestamp echo reply: 1714442625
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.005044000 seconds
# 	Time since previous frame in this TCP stream: 0.000297000 seconds
# 	SEQ/ACK analysis
# 	iRTT: 0.004747000 seconds
# 	Bytes in flight: 82
# 	Bytes sent since last PSH flag: 82
# 	TCP payload (82 bytes)
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	Kind: Time Stamp Option (8)
# Layer HTTP
# :	GET / HTTP/1.1\r\n
# 	Expert Info (Chat/Sequence): GET / HTTP/1.1\r\n
# 	GET / HTTP/1.1\r\n
# 	Severity level: Chat
# 	Group: Sequence
# 	Request Method: GET
# 	Request URI: /
# 	Request Version: HTTP/1.1
# 	Host: 192.168.8.125:11435\r\n
# 	User-Agent: curl/8.6.0\r\n
# 	Accept: */*\r\n
# 	Full request URI: http://192.168.8.125:11435/
# 	HTTP request 1/1
# 	\r\n
#
# Packet (Length: 200)
# Layer ETH
# :	Destination: f8:4d:89:80:34:90
# 	Address: f8:4d:89:80:34:90
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Source: 3c:9d:56:e1:2f:c6
# 	.... ..0. .... .... .... .... = LG bit: Globally unique address (factory default)
# 	.... ...0 .... .... .... .... = IG bit: Individual address (unicast)
# 	Type: IPv4 (0x0800)
# 	Address: 3c:9d:56:e1:2f:c6
# Layer IP
# :	0100 .... = Version: 4
# 	.... 0101 = Header Length: 20 bytes (5)
# 	Differentiated Services Field: 0x00 (DSCP: CS0, ECN: Not-ECT)
# 	0000 00.. = Differentiated Services Codepoint: Default (0)
# 	.... ..00 = Explicit Congestion Notification: Not ECN-Capable Transport (0)
# 	Total Length: 186
# 	Identification: 0xb0fd (45309)
# 	010. .... = Flags: 0x2, Don't fragment
# 	0... .... = Reserved bit: Not set
# 	.1.. .... = Don't fragment: Set
# 	..0. .... = More fragments: Not set
# 	...0 0000 0000 0000 = Fragment Offset: 0
# 	Time to Live: 63
# 	Protocol: TCP (6)
# 	Header Checksum: 0xfa0a [validation disabled]
# 	Header checksum status: Unverified
# 	Source Address: 192.168.8.125
# 	Destination Address: 192.168.6.104
# Layer TCP
# :	Source Port: 11435
# 	Destination Port: 55392
# 	Stream index: 5
# 	Conversation completeness: Incomplete, DATA (15)
# 	..0. .... = RST: Absent
# 	...0 .... = FIN: Absent
# 	.... 1... = Data: Present
# 	.... .1.. = ACK: Present
# 	.... ..1. = SYN-ACK: Present
# 	.... ...1 = SYN: Present
# 	Completeness Flags: ··DASS
# 	TCP Segment Len: 134
# 	Sequence Number: 1    (relative sequence number)
# 	Sequence Number (raw): 4162746490
# 	Next Sequence Number: 135    (relative sequence number)
# 	Acknowledgment Number: 83    (relative ack number)
# 	Acknowledgment number (raw): 2950180105
# 	1000 .... = Header Length: 32 bytes (8)
# 	Flags: 0x018 (PSH, ACK)
# 	000. .... .... = Reserved: Not set
# 	...0 .... .... = Accurate ECN: Not set
# 	.... 0... .... = Congestion Window Reduced: Not set
# 	.... .0.. .... = ECN-Echo: Not set
# 	.... ..0. .... = Urgent: Not set
# 	.... ...1 .... = Acknowledgment: Set
# 	.... .... 1... = Push: Set
# 	.... .... .0.. = Reset: Not set
# 	.... .... ..0. = Syn: Not set
# 	.... .... ...0 = Fin: Not set
# 	TCP Flags: ·······AP···
# 	Window: 509
# 	Calculated window size: 65152
# 	Window size scaling factor: 128
# 	Checksum: 0x0c80 [unverified]
# 	Checksum Status: Unverified
# 	Urgent Pointer: 0
# 	Options: (12 bytes), No-Operation (NOP), No-Operation (NOP), Timestamps
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	TCP Option - Timestamps: TSval 1714442629, TSecr 3384971114
# 	Length: 10
# 	Timestamp value: 1714442629
# 	Timestamp echo reply: 3384971114
# 	Timestamps
# 	Time since first frame in this TCP stream: 0.009144000 seconds
# 	Time since previous frame in this TCP stream: 0.000001000 seconds
# 	SEQ/ACK analysis
# 	iRTT: 0.004747000 seconds
# 	Bytes in flight: 134
# 	Bytes sent since last PSH flag: 134
# 	TCP payload (134 bytes)
# 	TCP Option - No-Operation (NOP)
# 	Kind: No-Operation (1)
# 	Kind: Time Stamp Option (8)
# Layer HTTP
# :	HTTP/1.1 200 OK\r\n
# 	Expert Info (Chat/Sequence): HTTP/1.1 200 OK\r\n
# 	HTTP/1.1 200 OK\r\n
# 	Severity level: Chat
# 	Group: Sequence
# 	Response Version: HTTP/1.1
# 	Status Code: 200
# 	Status Code Description: OK
# 	Response Phrase: OK
# 	Content-Type: text/plain; charset=utf-8\r\n
# 	Date: Fri, 23 Aug 2024 08:54:13 GMT\r\n
# 	Content-Length: 17\r\n
# 	Content length: 17
# 	HTTP response 1/1
# 	Time since request: 0.004100000 seconds
# 	Request in frame: 31
# 	Request URI: http://192.168.8.125:11435/
# 	File Data: 17 bytes
# 	\r\n
# Layer DATA-TEXT-LINES
# :	Ollama is running
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 11
#       9 # 打印捕获到的 HTTP 数据包
#      10 print('start')
# ---> 11 for packet in capture:
#      12     print(packet)
#      13     # print('Packet Number:', packet.number)
#      14     # print('Timestamp:', packet.sniff_time)
#      15     # print('Source IP:', packet.ip.src)
#      16     # print('Destination IP:', packet.ip.dst)
#
# File ~/opt/miniconda3/envs/py310_new/lib/python3.10/site-packages/pyshark/capture/capture.py:221, in Capture._packets_from_tshark_sync(self, packet_count, existing_process)
#     219 while True:
#     220     try:
# --> 221         packet, data = self.eventloop.run_until_complete(
#     222             parser.get_packets_from_stream(tshark_process.stdout, data,
#     223                                            got_first_packet=packets_captured > 0))
#     225     except EOFError:
#     226         self._log.debug("EOF reached (sync)")
#
# File ~/opt/miniconda3/envs/py310_new/lib/python3.10/site-packages/nest_asyncio.py:92, in _patch_loop.<locals>.run_until_complete(self, future)
#      90     f._log_destroy_pending = False
#      91 while not f.done():
# ---> 92     self._run_once()
#      93     if self._stopping:
#      94         break
#
# File ~/opt/miniconda3/envs/py310_new/lib/python3.10/site-packages/nest_asyncio.py:115, in _patch_loop.<locals>._run_once(self)
#     108     heappop(scheduled)
#     110 timeout = (
#     111     0 if ready or self._stopping
#     112     else min(max(
#     113         scheduled[0]._when - self.time(), 0), 86400) if scheduled
#     114     else None)
# --> 115 event_list = self._selector.select(timeout)
#     116 self._process_events(event_list)
#     118 end_time = self.time() + self._clock_resolution
#
# File ~/opt/miniconda3/envs/py310_new/lib/python3.10/selectors.py:562, in KqueueSelector.select(self, timeout)
#     560 ready = []
#     561 try:
# --> 562     kev_list = self._selector.control(None, max_ev, timeout)
#     563 except InterruptedError:
#     564     return ready
#
# KeyboardInterrupt:

# %%
packet.number
# Out:
# '112'

# %%
print('Packet Number:', packet.number)
print('Timestamp:', packet.sniff_time)
print('Source IP:', packet.ip.src)
print('Destination IP:', packet.ip.dst)
# Out:
# Packet Number: 112
# Timestamp: 2024-08-23 15:44:49.162464
# Source IP: 36.139.251.87
# Destination IP: 192.168.6.104

# %%
if 'http' in packet:
    print('HTTP Method:', packet.http.request_method)
    print('HTTP Host:', packet.http.host)

# %%
import pyshark

# 捕获网络接口上的流量
capture = pyshark.LiveCapture(interface='eth0')

# 捕获流量，设置超时时间为50秒
capture.sniff(timeout=50)

# 访问数据包内容
for packet in capture:
    print('Packet Number:', packet.number)
    print('Timestamp:', packet.sniff_time)
    print('Source IP:', packet.ip.src)
    print('Destination IP:', packet.ip.dst)
    if 'http' in packet:
        print('HTTP Method:', packet.http.request_method)
        print('HTTP Host:', packet.http.host)
